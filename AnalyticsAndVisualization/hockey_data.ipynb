# %%
import pandas as pd

# %%
df1 = pd.read_csv("skaters.csv")

# %%
df1.head(10)
# Out:
#    playerId  season             name team position situation  games_played  \
# 0   8480950    2023  Ilya Lyubushkin  TOR        D     other            74
# 1   8480950    2023  Ilya Lyubushkin  TOR        D       all            74
# 2   8480950    2023  Ilya Lyubushkin  TOR        D      5on5            74
# 3   8480950    2023  Ilya Lyubushkin  TOR        D      4on5            74
# 4   8480950    2023  Ilya Lyubushkin  TOR        D      5on4            74
# 5   8478438    2023      Tommy Novak  NSH        C     other            71
# 6   8478438    2023      Tommy Novak  NSH        C       all            71
# 7   8478438    2023      Tommy Novak  NSH        C      5on5            71
# 8   8478438    2023      Tommy Novak  NSH        C      4on5            71
# 9   8478438    2023      Tommy Novak  NSH        C      5on4            71
#
#    icetime  shifts  gameScore  ...  OffIce_F_xGoals  OffIce_A_xGoals  \
# 0   2881.0    56.0       5.08  ...            18.00            21.61
# ...

# %%
dfu = pd.read_csv("skatersU.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dfu = pd.read_csv("skatersU.csv")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...
